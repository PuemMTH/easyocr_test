# %%
import os
import random
import matplotlib.pyplot as plt
import easyocr
import csv
import pandas as pd

from utils.config import get_model_configurations, get_dataset_configurations
from utils.dataset_loader import load_dataset, create_sample_dataset, create_balanced_sample_dataset
from utils.ocr_evaluator import run_ocr_evaluation, calculate_metrics, print_summary_statistics

# %%
# Paths - ให้ output อยู่ที่เดียวกับ input
input_file = '/Volumes/BACKUP/data/processed_lmdb_format/lmdb/test/labels.csv'
output_file = '/Volumes/BACKUP/data/processed_lmdb_format/lmdb/test/labels_fixed.csv'

print(f"📥 Input: {input_file}")
print(f"📤 Output: {output_file}")

# Quick fix
try:
    df = pd.read_csv(input_file, encoding='utf-8-sig', on_bad_lines='skip')
    df.to_csv(output_file, index=False)
    print(f"✅ Fixed! {len(df)} rows")
except:
    # Manual fix
    with open(input_file, 'r', encoding='utf-8', errors='ignore') as f, \
         open(output_file, 'w', encoding='utf-8', newline='') as out:
        
        writer = csv.writer(out)
        writer.writerow(['filename', 'words'])
        
        count = 0
        for i, line in enumerate(f):
            if i == 0 or not line.strip(): continue
            if ',' in line:
                parts = line.strip().split(',', 1)
                if len(parts) == 2 and parts[0].endswith('.png'):
                    writer.writerow([parts[0].strip(), parts[1].strip()])
                    count += 1
        print(f"✅ Manual fix: {count} rows")

# Test
df = pd.read_csv(output_file)
print(f"Final: {len(df)} rows")
print(df.head(2))
# Out:
# 📥 Input: /Volumes/BACKUP/data/processed_lmdb_format/lmdb/test/labels.csv
# 📤 Output: /Volumes/BACKUP/data/processed_lmdb_format/lmdb/test/labels_fixed.csv
# ✅ Fixed! 940 rows
# Final: 940 rows
#                                    filename                       words
# 0  424dd150-9379-4fd9-94ef-8820550e879b.png  พล.ร.อ.เชิงชาย ชมเชิงแพทย์
# 1  de791b60-8f12-4587-83f9-2d33fa967c43.png             คุยโขมงบ่าย3โมง

# %%
import csv
import os

def txt_to_csv(input_file, output_file):
    """Convert tab-separated .txt file to CSV with filename and words columns"""
    filename = os.path.splitext(os.path.basename(input_file))[0]
    
    with open(input_file, 'r', encoding='utf-8') as txt_file, \
         open(output_file, 'w', newline='', encoding='utf-8') as csv_file:
        
        writer = csv.writer(csv_file)
        writer.writerow(['filename', 'words'])  # Header
        
        for line in txt_file:
            words = [word.strip() for word in line.strip().split('\t') if word.strip()]
            for word in words:
                writer.writerow([filename, word])

# Usage example
txt_to_csv('/project/lt200384-ff_bio/puem/ocr/dataset/processed_lmdb_format/test/labels.txt', '/project/lt200384-ff_bio/puem/ocr/dataset/processed_lmdb_format/test/labels.csv')

# %%
models_to_test = get_model_configurations(models=[
    {
        'name': 'base_model',
        'reader': easyocr.Reader(
            lang_list=['en', 'th'],
            detector=False,
            gpu=True,
            download_enabled=False
        )
    },
    {
        'name': 'out_source_merge_kaggle_data_3gpus',
        'reader': easyocr.Reader(
            lang_list=['en','th'],
            detector=False,
            gpu=True,
            download_enabled=False,
            recog_network='out_source_merge_kaggle_data_3gpus',
            model_storage_directory='./custom_example/model',
            user_network_directory='./custom_example/user_network'
        )
    },
    {
        'name': 'out_source_merge_kaggle_data_freeze_sequence_config_3gpus',
        'reader': easyocr.Reader(
            lang_list=['en','th'],
            detector=False,
            gpu=True,
            download_enabled=False,
            recog_network='out_source_merge_kaggle_data_freeze_sequence_config_3gpus',
            model_storage_directory='./custom_example/model',
            user_network_directory='./custom_example/user_network'
        )
    },
    {
        'name': 'out_source_only_data_3gpus',
        'reader': easyocr.Reader(
            lang_list=['en','th'],
            detector=False,
            gpu=True,
            download_enabled=False,
            recog_network='out_source_only_data_3gpus',
            model_storage_directory='./custom_example/model',
            user_network_directory='./custom_example/user_network'
        )
    }
])
datasets_to_test = get_dataset_configurations(datasets=[
    {
        'name': 'processed_lmdb_format',
        'type': 'lmdb_format',
        'folder_path': '/project/lt200384-ff_bio/puem/ocr/dataset/processed_lmdb_format/test',
        'df': pd.read_csv('/project/lt200384-ff_bio/puem/ocr/dataset/processed_lmdb_format/test/labels.csv'),
    },
    {
        'name': 'kaggle_test',
        'type': 'lmdb_format',
        'folder_path': '/project/lt200384-ff_bio/puem/ocr/dataset/kaggle_test',
        'df': pd.read_csv('/project/lt200384-ff_bio/puem/ocr/dataset/kaggle_test/labels.csv'),
    }
    # /project/lt200384-ff_bio/puem/ocr/dataset/kaggle_test
])

EVALUATION_SAMPLE_SIZE = -1
USE_BALANCED_SAMPLING = True
# Out:
# Loaded 4 models for testing:
# - base_model
# - out_source_merge_kaggle_data_3gpus
# - out_source_merge_kaggle_data_freeze_sequence_config_3gpus
# - out_source_only_data_3gpus
# Loaded 2 datasets:
# - processed_lmdb_format (lmdb_format) - 1916 files
# - kaggle_test (lmdb_format) - 10000 files

# %%
all_results = []
for dataset in datasets_to_test:
    print(f"\nProcessing dataset: {dataset['name']}")
    if USE_BALANCED_SAMPLING and EVALUATION_SAMPLE_SIZE != -1:
        test_dataset = create_balanced_sample_dataset(dataset, EVALUATION_SAMPLE_SIZE)
        if 'estimated_images' in test_dataset:
            print(f"🎯 Balanced sampling: Using ~{test_dataset['estimated_images']} images to target {EVALUATION_SAMPLE_SIZE} samples")
    else:
        test_dataset = create_sample_dataset(dataset, EVALUATION_SAMPLE_SIZE)
    dataset_results = load_dataset(test_dataset, test_dataset['type'])
    
    if len(dataset_results) == 0:
        print(f"⚠️  No data loaded for {dataset['name']}")
        continue
    
    expected_msg = "full dataset" if EVALUATION_SAMPLE_SIZE == -1 else f"~{EVALUATION_SAMPLE_SIZE} samples"
    print(f"📊 Using {len(dataset_results)} samples for evaluation (target: {expected_msg})")
    
    # Run OCR evaluation with all models
    model_results = run_ocr_evaluation(models_to_test, dataset_results, dataset['name'])
    all_results.extend(model_results)

print(f"\n✓ Total processed results: {len(all_results)}")
sampling_type = "Balanced" if USE_BALANCED_SAMPLING else "Standard"
print(f"📈 {sampling_type} sampling for fairer comparison across datasets")
# Out:
# Processing dataset: processed_lmdb_format
# Loading dataset: processed_lmdb_format (type: lmdb_format)
# DataFrame shape: (1916, 2)
# Using filename column: 'filename', text column: 'words'
# Processing lmdb_format:  43%|████▎     | 817/1916 [00:00<00:00, 8167.07it/s]
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# ...
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Processing lmdb_format:  88%|████████▊ | 1679/1916 [00:00<00:00, 8432.91it/s]
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Processing lmdb_format: 100%|██████████| 1916/1916 [00:00<00:00, 8380.46it/s]
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Warning: Image not found for labels
# Loaded 0 samples
# ⚠️  No data loaded for processed_lmdb_format
#
# Processing dataset: kaggle_test
# Loading dataset: kaggle_test (type: lmdb_format)
# DataFrame shape: (10000, 2)
# Using filename column: 'filename', text column: 'words'
# Processing lmdb_format: 100%|██████████| 10000/10000 [00:03<00:00, 2606.92it/s]
# Loaded 10000 samples
# 📊 Using 10000 samples for evaluation (target: full dataset)
#   Testing model: base_model
# OCR with base_model: 100%|██████████| 10000/10000 [01:58<00:00, 84.23it/s]
#   Completed 10000 images
#   Testing model: out_source_merge_kaggle_data_3gpus
# OCR with out_source_merge_kaggle_data_3gpus: 100%|██████████| 10000/10000 [01:44<00:00, 95.26it/s]
#   Completed 10000 images
#   Testing model: out_source_merge_kaggle_data_freeze_sequence_config_3gpus
# OCR with out_source_merge_kaggle_data_freeze_sequence_config_3gpus: 100%|██████████| 10000/10000 [01:44<00:00, 95.63it/s]
#   Completed 10000 images
#   Testing model: out_source_only_data_3gpus
# OCR with out_source_only_data_3gpus: 100%|██████████| 10000/10000 [01:51<00:00, 89.48it/s]
#   Completed 10000 images
#
# ✓ Total processed results: 40000
# 📈 Balanced sampling for fairer comparison across datasets

# %%
# print(all_results)
types_list = [result['dataset_name'] for result in all_results]
print(f"🔍 Types of results collected: {set(types_list)}")

img = [x for x in all_results if x['dataset_name'] == 'data_from_outsource' and x['model_name'] == 'base_model']
random.seed(47)
img = random.sample(img, min(5, len(img)))
# for i, in enumerate(img):
for index, val in enumerate(img):
    plt.figure(figsize=(10, 3))
    plt.imshow(val['cropped_image'])
    plt.axis('off')
    os.makedirs("tmp", exist_ok=True)
    plt.savefig(f"output/sample_image_{index+1}_{val['dataset_name']}_{val['model_name']}.png", bbox_inches='tight', pad_inches=0.1)
    plt.show()
# Out:
# 🔍 Types of results collected: {'kaggle_test'}

# %%
print("=== METRICS CALCULATION ===")
if len(all_results) > 0:
    metrics_output_path = './output/evaluation_results.json'
    individual_metrics = calculate_metrics(all_results, metrics_output_path)
    print_summary_statistics(individual_metrics)
    print(f"\n✓ Evaluation complete! Results saved to {metrics_output_path}")
else:
    print("⚠️  No results to calculate metrics")
# Out:
# === METRICS CALCULATION ===
# Warning: Could not load semantic model: (MaxRetryError("HTTPSConnectionPool(host='huggingface.co', port=443): Max retries exceeded with url: /api/models/sentence-transformers/distiluse-base-multilingual-cased/tree/main/additional_chat_templates?recursive=False&expand=False (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f5750c71e50>: Failed to establish a new connection: [Errno 101] Network is unreachable'))"), '(Request ID: 0e852c5a-f626-4a5f-a5e8-e280b683b1c0)')
# Calculating metrics for kaggle_test_base_model
# Metrics for kaggle_test_base_model:  10%|█         | 1035/10000 [00:00<00:02, 3207.91it/s]
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Metrics for kaggle_test_base_model:  21%|██        | 2120/10000 [00:00<00:01, 4456.14it/s]
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# ...
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# Semantic model not loaded
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 if len(all_results) > 0:
#       3     metrics_output_path = './output/evaluation_results.json'
# ----> 4     individual_metrics = calculate_metrics(all_results, metrics_output_path)
#       5     print_summary_statistics(individual_metrics)
#       6     print(f"\n✓ Evaluation complete! Results saved to {metrics_output_path}")
#
# File /lustrefs/disk/project/lt200384-ff_bio/puem/ocr/ocr_list/easyocr_test_v2/utils/ocr_evaluator.py:107, in calculate_metrics(results, output_path)
#     105 # Save metrics to file if path provided
#     106 if output_path:
# --> 107     with open(output_path, 'w', encoding='utf-8') as f:
#     108         json.dump(individual_metrics, f, ensure_ascii=False, indent=4)
#     109     print(f"Saved {len(individual_metrics)} metric results to {output_path}")
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/evaluation_results.json'
